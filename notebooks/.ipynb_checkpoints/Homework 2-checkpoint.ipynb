# %% [markdown]
# # <center> Homework 2 (Topics 5-7: Groupby, Merge, Visualization)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Ещё раз (как и в задании 1) считайте в переменные tr_mcc_codes, tr_types, transactions и customers_gender_train. В transactions опять считайте только первые 1000000 строк.

# %%
tr_mcc_codes = pd.read_csv("../data/tr_mcc_codes.csv", sep=";", index_col="mcc_code")
print("**tr_mcc_codes","\n\r",tr_mcc_codes.head())

tr_types = pd.read_csv("../data/tr_types.csv", sep=";", index_col="tr_type")
print("\n\r**tr_types","\n\r",tr_types.head())

transactions = pd.read_csv("../data/transactions.csv", sep=",", nrows=1000000, index_col="customer_id")
print("\n\r**transactions","\n\r",transactions.head())

customers_gender_train = pd.read_csv("../data/gender_train.csv", sep=",", index_col="customer_id")
print("\n\r**gender_train","\n\r",customers_gender_train.head())
# Out:
# **tr_mcc_codes
#                                              mcc_description
# mcc_code
# 742                                     Ветеринарные услуги
# 1711      Генеральные подрядчики по вентиляции, теплосна...
# 1731                            Подрядчики по электричеству
# 1799      Подрядчики, специализированная торговля — нигд...
# 2741               Разнообразные издательства/печатное дело
#
# **tr_types
#                                              tr_description
# tr_type
# 3200     Плата за предоставление услуг посредством моби...
# 3210     Плата за предоставление отчета по счету карты ...
# 3800     Плата за обслуживание банковской карты (за пер...
# 4000               Плата за получение наличных в Сбербанке
# 4001     Плата за получение наличных в Сбербанке (в дру...
#
# **transactions
#              tr_datetime  mcc_code  tr_type    amount term_id
# customer_id
# 39026145     0 10:23:26      4814     1030  -2245.92     NaN
# ...

# %% [markdown]
# #### Task 0.
# Соедините transactions с всеми остальными таблицами (tr_mcc_codes, tr_types, gender_train). Причём с customers_gender_train необходимо смёрджиться с помощью left join, а с оставшимися датафреймами - через inner.
# После получения результата таблицы gender_train, tr_types, tr_mcc_codes можно удалить. В результате соединения датафреймов должно получиться 999584 строки.

# %%
transactions.head()
# Out:
#             tr_datetime  mcc_code  tr_type    amount term_id
# customer_id
# 39026145     0 10:23:26      4814     1030  -2245.92     NaN
# 39026145     1 10:19:29      6011     7010  56147.89     NaN
# 39026145     1 10:20:56      4829     2330 -56147.89     NaN
# 39026145     1 10:39:54      5499     1010  -1392.47     NaN
# 39026145     2 15:33:42      5499     1010   -920.83     NaN

# %%
customers_gender_train.head()
# Out:
#              gender
# customer_id
# 10928546          1
# 69348468          1
# 61009479          0
# 74045822          0
# 27979606          1

# %%
main_table = pd.merge (transactions, customers_gender_train, on='customer_id', how='left')
main_table = pd.merge (pd.merge(main_table, tr_mcc_codes, on='mcc_code', how='inner'), tr_types, on='tr_type', how='inner')
#main_table.query('mcc_code == 5992')

# %%
main_table.count()
# Out:
# tr_datetime        999584
# mcc_code           999584
# tr_type            999584
# amount             999584
# term_id            577482
# gender             600086
# mcc_description    999584
# tr_description     999584
# dtype: int64

# %%
#del (tr_types, tr_mcc_codes, customers_gender_train)

# %% [markdown]
# #### Task 1.
# 1. Определите модуль разницы между средними тратами женщин и мужчин (трата - отрицательное значение amount). (*)
#
# Выведите ответ в виде вещественного числа, округлённого до двух знаков после запятой, отделив дробную часть точкой в формате "123.45"
#
#
# <B>32718.05</B>
# ##### Пояснения:
# (\*) Если в результате для мужчин получились значения [-1,-3,-5], а для женщин [-1,-2,-3],
# то модуль разницы между средними -3 и -2 будет равен 1.
#
# (\**) Обратите внимание, что для вычисления модуля разности точных знаний о том,
# какой класc относится к мужчинам, а какой - к женщинам, пока не требуется.

# %%
filter1 = main_table['gender'] == 1
filter2 = main_table['amount'] > 0
task1_g1 = main_table.where(filter1 & filter2, inplace = False)
filter1 = main_table['gender'] == 0
filter2 = main_table['amount'] > 0
task1_g2 = main_table.where(filter1 & filter2, inplace = False)

# %%
print ('man-',task1_g1.gender.count())
print ('women-',task1_g2.gender.count())
# Out:
# man- 128018
# women- 43303

# %%
print (main_table[main_table.gender == 0].amount.mean() - main_table[main_table.gender == 1].amount.mean())
filter1 = main_table['gender'] == 1
filter2 = main_table['amount'] < 0
task1_g1 = main_table.where(filter1 & filter2, inplace = False)
filter1 = main_table['gender'] == 0
filter2 = main_table['amount'] < 0
task1_g2 = main_table.where(filter1 & filter2, inplace = False)
# Out:
# 2633.0244259066603

# %%
task1_g1.amount.mean() - task1_g2.amount.mean()
# Out:
# -32718.05492021877

# %%
task1_g2.amount.mean() - task1_g1.amount.mean()
# Out:
# 32718.05492021877

# %% [markdown]
# #### Task 2:
# 1. Создайте новый столбец - mcc_code+tr_type, сконкатенировав значения из соответствующих столбцов. (\*)
# 2. Для получившегося столбца определите дисперсию сумм трат тех категорий, в которых не менее 10 наблюдений.
# 3. Определите отношение максимальной дисперсии к минимальной.
#
# Выведите ответ в виде вещественного числа, округлённого до ближайшего целого в формате "123456" без дробной части.
#
# <B>9170599</B>
#
# ##### Пояснения:
# (\*) Для конкатенации значений в столбцах можно использовать метод .astype(str) для серии и складывать соовтетствующие серии.     Либо же применять apply к строкам датафрейма, прописывая логику преобразования и конкатенации значений внутри.

# %%
main_table.head()
# Out:
#    tr_datetime  mcc_code  tr_type   amount term_id  gender  \
# 0   0 10:23:26      4814     1030 -2245.92     NaN     1.0
# 1   6 07:08:31      4814     1030 -5614.79     NaN     1.0
# 2   8 07:06:10      4814     1030 -1122.96     NaN     1.0
# 3  11 08:49:03      4814     1030 -2245.92     NaN     1.0
# 4  11 14:12:08      4814     1030 -2245.92     NaN     1.0
#
#                                      mcc_description  \
# 0  Звонки с использованием телефонов, считывающих...
# 1  Звонки с использованием телефонов, считывающих...
# 2  Звонки с использованием телефонов, считывающих...
# 3  Звонки с использованием телефонов, считывающих...
# 4  Звонки с использованием телефонов, считывающих...
#
#                    tr_description
# 0  Оплата услуги. Банкоматы СБ РФ
# 1  Оплата услуги. Банкоматы СБ РФ
# 2  Оплата услуги. Банкоматы СБ РФ
# 3  Оплата услуги. Банкоматы СБ РФ
# 4  Оплата услуги. Банкоматы СБ РФ

# %%
main_table['mcc_code+tr_type'] = main_table.mcc_code.astype(str)+main_table.tr_type.astype(str)
main_groups = main_table.groupby(['mcc_code+tr_type'])
main_groups_more10 = main_groups.size()[main_groups.size() > 10]
main_groups_more10.head()
# Out:
# mcc_code+tr_type
# 17111110     18
# 17991110     57
# 30001010    482
# 30001100     92
# 30001110     12
# dtype: int64

# %%
main_group_var = main_groups.amount.var()
main_group_var.head()
# Out:
# mcc_code+tr_type
# 17111110    4.029687e+10
# 17311010    5.335287e+08
# 17311110             NaN
# 17991110    1.804924e+10
# 27411110    1.650985e+09
# Name: amount, dtype: float64

# %%
main_finsh = pd.merge(main_groups_more10.rename('more10'), main_group_var.rename('var'), on='mcc_code+tr_type')
main_finsh.head()
# Out:
#                   more10           var
# mcc_code+tr_type
# 17111110              18  4.029687e+10
# 17991110              57  1.804924e+10
# 30001010             482  2.762345e+11
# 30001100              92  8.796329e+10
# 30001110              12  4.452301e+10

# %%
main_finsh['var'].max()
# Out:
# 12037786958150.154

# %%
main_finsh['var'].min()
# Out:
# 1312650.0193129827

# %%
main_finsh['var'].max()/main_finsh['var'].min()
# Out:
# 9170599.00280999

# %% [markdown]
# #### Task 3:
# 1. Для каждого пола выделите 5 типов транзакций, по которым максимальная сумма прихода на карту (строго положительная) была минимальной среди всех типов. (\*)
# 2. Выделите среди них те, которые встречаются одновременно и у мужчин, и у женщин:
#     - 1) Покупка. POS ТУ СБ РФ
#     - 2) Списание после проведения претензионной работы
#     - 3) Плата за получение наличных. Россия
#     - 4) Перевод на карту/ с карты через АТМ (со взиманием комиссии с отправителя) по счету в овердрафте
#     - +5) Плата за получение наличных в АТМ. Россия
#     - 6) Наличные. Зарубеж. банк
#     - 7) Возврат покупки. POS ТУ Россия
#
# ##### Пояснения:
# (\*) Если максимальные суммы приходов по каким-то типам были равны [1,2,3,4,5,6,7,8], то 5 минимальных из них: [1,2,3,4,5]

# %%
main_table.head()
# Out:
#    tr_datetime  mcc_code  tr_type   amount term_id  gender  \
# 0   0 10:23:26      4814     1030 -2245.92     NaN     1.0
# 1   6 07:08:31      4814     1030 -5614.79     NaN     1.0
# 2   8 07:06:10      4814     1030 -1122.96     NaN     1.0
# 3  11 08:49:03      4814     1030 -2245.92     NaN     1.0
# 4  11 14:12:08      4814     1030 -2245.92     NaN     1.0
#
#                                      mcc_description  \
# 0  Звонки с использованием телефонов, считывающих...
# 1  Звонки с использованием телефонов, считывающих...
# 2  Звонки с использованием телефонов, считывающих...
# 3  Звонки с использованием телефонов, считывающих...
# 4  Звонки с использованием телефонов, считывающих...
#
#                    tr_description mcc_code+tr_type
# 0  Оплата услуги. Банкоматы СБ РФ         48141030
# 1  Оплата услуги. Банкоматы СБ РФ         48141030
# 2  Оплата услуги. Банкоматы СБ РФ         48141030
# 3  Оплата услуги. Банкоматы СБ РФ         48141030
# ...

# %%
main_group_T3_G1 = main_table.query('gender == 1').groupby(['tr_type'])
main_group_T3_G0 = main_table.query('gender == 0').groupby(['tr_type'])
#print (main_group_T3.get_group(6010))
#print (main_group_T3_G0.size().head())
#print (main_group_T3_G1.size().head())
print (pd.merge(tr_types, main_group_T3_G0.amount.max()[main_group_T3_G0.amount.max()>0].sort_values().head().map("{:.2f}".format), on='tr_type'))
print (pd.merge(tr_types, main_group_T3_G1.amount.max()[main_group_T3_G1.amount.max()>0].sort_values().head().map("{:.2f}".format), on='tr_type'))
# Out:
#                                             tr_description   amount
# tr_type
# 4051     Плата за перевод на карту (с карты) через АТМ ...  1122.96
# 4100                   Плата за получение наличных. Россия  5041.86
# 4110             Плата за получение наличных в АТМ. Россия  2245.92
# 4210           Плата за получение наличных в АТМ. Зарубеж.  2245.92
# 2370     Списание с карты на карту по операции <перевод...  2335.75
#                                          tr_description    amount
# tr_type
# 4110          Плата за получение наличных в АТМ. Россия   2245.92
# 6000                         Возврат  покупки. ТУ СБ РФ  79280.83
# 8100     Списание после проведения претензионной работы  64682.37
# 1010                              Покупка. POS ТУ СБ РФ  28803.87
# 2020                Выдача наличных через POS Сбербанка   2245.92

# %% [markdown]
# #### Task 4:
# 1. Выделите из поля tr_datetime относительный день tr_day (первое число до точного времени). (\*)
# 2. Отфильтруйте строки таким образом, чтобы оставить только те транзакции, у которых в соответствующий относительный день tr_day количество уникальных MCC кодов при транзакциях было больше 75.
# 3. Сгруппируйте полученный отфильтрованный датафрейм по MCC коду и полу, после чего, пронализировав результат, выберите верные варианты ответов ниже (\**):
#     - +1) gender == 0 - женщины, gender == 1 - мужчины
#     - 2) gender == 1 - женщины, gender == 0 - мужчины
#     - +3) Абсолютное значение медианы с типом "Флористика" (расходов/приходов) у мужчин выше той же медианы у женщин
#     - 4) Абсолютное значение медианы женских трат (расходов/приходов) на ценные бумаги выше мужских
#     - +5) Абсолютное значение медианы женских трат (расходов/приходов) в категории "Бары, коктейль-бары, дискотеки, ночные клубы и таверны — места продажи алкогольных напитков" ниже мужских
#
# ##### Пояснения:
# (\*) Для того, чтобы выделить всё, что стоит до первого пробела, можо использовать строковые методы для датафрейма - .str.split(), например. Либо же реализовывать логику выделения подстроки с помощью метода apply. <br>
# (\**) Понять, какой класс к какому типу транзакций (мужские/женские) относится можно, если поизучать типичные для мужчин/женщин категории и сравнить средние/медианы расходов и/или приходов в них.

# %%
import re
main_table.head()
# Out:
#    tr_datetime  mcc_code  tr_type   amount term_id  gender  \
# 0   0 10:23:26      4814     1030 -2245.92     NaN     1.0
# 1   6 07:08:31      4814     1030 -5614.79     NaN     1.0
# 2   8 07:06:10      4814     1030 -1122.96     NaN     1.0
# 3  11 08:49:03      4814     1030 -2245.92     NaN     1.0
# 4  11 14:12:08      4814     1030 -2245.92     NaN     1.0
#
#                                      mcc_description  \
# 0  Звонки с использованием телефонов, считывающих...
# 1  Звонки с использованием телефонов, считывающих...
# 2  Звонки с использованием телефонов, считывающих...
# 3  Звонки с использованием телефонов, считывающих...
# 4  Звонки с использованием телефонов, считывающих...
#
#                    tr_description mcc_code+tr_type
# 0  Оплата услуги. Банкоматы СБ РФ         48141030
# 1  Оплата услуги. Банкоматы СБ РФ         48141030
# 2  Оплата услуги. Банкоматы СБ РФ         48141030
# 3  Оплата услуги. Банкоматы СБ РФ         48141030
# ...

# %%
f = lambda x: re.findall(r'(\d+)\s', x)[0]
main_table['tr_day'] = main_table.tr_datetime.apply(f)
main_table.head()
# Out:
#    tr_datetime  mcc_code  tr_type   amount term_id  gender  \
# 0   0 10:23:26      4814     1030 -2245.92     NaN     1.0
# 1   6 07:08:31      4814     1030 -5614.79     NaN     1.0
# 2   8 07:06:10      4814     1030 -1122.96     NaN     1.0
# 3  11 08:49:03      4814     1030 -2245.92     NaN     1.0
# 4  11 14:12:08      4814     1030 -2245.92     NaN     1.0
#
#                                      mcc_description  \
# 0  Звонки с использованием телефонов, считывающих...
# 1  Звонки с использованием телефонов, считывающих...
# 2  Звонки с использованием телефонов, считывающих...
# 3  Звонки с использованием телефонов, считывающих...
# 4  Звонки с использованием телефонов, считывающих...
#
#                    tr_description mcc_code+tr_type tr_day amount_bucket  \
# 0  Оплата услуги. Банкоматы СБ РФ         48141030      0      Very Low
# 1  Оплата услуги. Банкоматы СБ РФ         48141030      6           Low
# ...

# %%
main_group_T4 = main_table.groupby(['tr_day','mcc_code'])
unique_mcc = main_group_T4.size()[main_group_T4.size()>75]
#print (type (main_table))
#main_table.dtypes
f = lambda x: x.mcc_code.count() > 75
main_group_T4_ = main_table.groupby(['tr_day','mcc_code']).filter(f)
#type (unique_mcc)

# %%
unique_mcc.unstack().head()
# Out:
# mcc_code   4814   4829   5411  5499   6010   6011  5964  5541  5912
# tr_day
# 0         319.0  158.0  241.0  82.0  385.0  514.0   NaN   NaN   NaN
# 1         203.0   88.0  254.0  95.0  166.0  395.0   NaN   NaN   NaN
# 10        274.0  121.0  222.0  77.0  227.0  461.0   NaN   NaN   NaN
# 100       189.0   91.0  272.0   NaN  308.0  311.0   NaN   NaN   NaN
# 101       249.0  220.0  243.0  87.0  327.0  488.0   NaN   NaN   NaN

# %%
main_temp = main_group_T4_.groupby(['tr_day','mcc_code'])
main_temp.size().unstack().head()
# Out:
# mcc_code   4814   4829   5411  5499  5541  5912  5964   6010   6011
# tr_day
# 0         319.0  158.0  241.0  82.0   NaN   NaN   NaN  385.0  514.0
# 1         203.0   88.0  254.0  95.0   NaN   NaN   NaN  166.0  395.0
# 10        274.0  121.0  222.0  77.0   NaN   NaN   NaN  227.0  461.0
# 100       189.0   91.0  272.0   NaN   NaN   NaN   NaN  308.0  311.0
# 101       249.0  220.0  243.0  87.0   NaN   NaN   NaN  327.0  488.0

# %%
print(type(main_group_T4))
print(type(main_group_T4_))
main_group_T4_.head()
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# <class 'pandas.core.frame.DataFrame'>
#    tr_datetime  mcc_code  tr_type   amount term_id  gender  \
# 0   0 10:23:26      4814     1030 -2245.92     NaN     1.0
# 1   6 07:08:31      4814     1030 -5614.79     NaN     1.0
# 2   8 07:06:10      4814     1030 -1122.96     NaN     1.0
# 3  11 08:49:03      4814     1030 -2245.92     NaN     1.0
# 4  11 14:12:08      4814     1030 -2245.92     NaN     1.0
#
#                                      mcc_description  \
# 0  Звонки с использованием телефонов, считывающих...
# 1  Звонки с использованием телефонов, считывающих...
# 2  Звонки с использованием телефонов, считывающих...
# 3  Звонки с использованием телефонов, считывающих...
# 4  Звонки с использованием телефонов, считывающих...
#
#                    tr_description mcc_code+tr_type tr_day amount_bucket  \
# 0  Оплата услуги. Банкоматы СБ РФ         48141030      0      Very Low
# ...

# %%
main_group_T4_.groupby(['gender','mcc_description']).size().unstack()
# Out:
# mcc_description  Аптеки  Бакалейные магазины, супермаркеты  Денежные переводы  \
# gender
# 0.0                  30                              41183              23457
# 1.0                  12                              38650              20266
#
# mcc_description  Звонки с использованием телефонов, считывающих магнитную ленту  \
# gender
# 0.0                                                          39527
# 1.0                                                          28637
#
# mcc_description  Прямой маркетинг — торговля через каталог  \
# gender
# 0.0                                                     57
# 1.0                                                     10
#
# mcc_description  Различные продовольственные магазины — рынки, магазины со спец-ассортиментом, продажа полуфабрикатов, фирменных блюд, продажа с помощью торговых автоматов  \
# gender
# 0.0                                                          11772
# ...

# %%
main_group_T4_.groupby(['gender','mcc_description']).amount.median().map("{:.2f}".format).unstack()
# Out:
# mcc_description    Аптеки Бакалейные магазины, супермаркеты Денежные переводы  \
# gender
# 0.0              -8604.55                          -8494.95         -22459.16
# 1.0              -4143.72                          -7844.98         -65131.56
#
# mcc_description Звонки с использованием телефонов, считывающих магнитную ленту  \
# gender
# 0.0                                                       -2245.92
# 1.0                                                       -3144.28
#
# mcc_description Прямой маркетинг — торговля через каталог  \
# gender
# 0.0                                              -5102.95
# 1.0                                              -8663.28
#
# mcc_description Различные продовольственные магазины — рынки, магазины со спец-ассортиментом, продажа полуфабрикатов, фирменных блюд, продажа с помощью торговых автоматов  \
# gender
# 0.0                                                       -5176.39
# ...

# %%
main_table.groupby(['gender','mcc_description']).amount.median().map("{:.2f}".format).unstack()
# Out:
# mcc_description Авиалинии, авиакомпании  \
# gender
# 0.0                          -266388.07
# 1.0                          -214560.20
#
# mcc_description Авиалинии, авиакомпании, нигде более не классифицированные  \
# gender
# 0.0                                                     -138123.82
# 1.0                                                     -172598.63
#
# mcc_description Автобусные линии Автозапчасти и аксессуары  \
# gender
# 0.0                    -49994.99                 -11793.64
# 1.0                    -17610.67                 -13161.07
#
# mcc_description Автоматизированные бензозаправки  Автомойки    Автошины  \
# gender
# 0.0                                    -18360.36  -11229.58  -115103.18
# 1.0                                    -27194.11   -9882.03   -57046.26
#
# mcc_description Агентства по автотранспортным перевозкам, местные/дальные автогрузоперевозки, компании попереезду и хранению, местная доставка  \
# gender
# ...

# %%
main_table.groupby(['gender','mcc_description']).amount.count().map("{:.2f}".format).unstack()
# Out:
# mcc_description Авиалинии, авиакомпании  \
# gender
# 0.0                              170.00
# 1.0                              288.00
#
# mcc_description Авиалинии, авиакомпании, нигде более не классифицированные  \
# gender
# 0.0                                                         197.00
# 1.0                                                         209.00
#
# mcc_description Автобусные линии Автозапчасти и аксессуары  \
# gender
# 0.0                        12.00                    288.00
# 1.0                        25.00                   1142.00
#
# mcc_description Автоматизированные бензозаправки Автомойки Автошины  \
# gender
# 0.0                                         5.00     19.00     4.00
# 1.0                                        78.00    137.00    34.00
#
# mcc_description Агентства по автотранспортным перевозкам, местные/дальные автогрузоперевозки, компании попереезду и хранению, местная доставка  \
# gender
# ...

# %%
main_table.query('mcc_code == 5992').groupby(['gender','mcc_description']).amount.count().map("{:.2f}".format).unstack()
# Out:
# mcc_description Флористика
# gender
# 0.0                 247.00
# 1.0                 293.00

# %%
main_table.query('mcc_code == 5992').groupby(['gender','mcc_description']).amount.median().map("{:.2f}".format).unstack()
# Out:
# mcc_description Флористика
# gender
# 0.0              -12352.54
# 1.0              -19090.28

# %%
main_table.query('mcc_code == 6211').groupby(['gender','mcc_description']).amount.count().map("{:.2f}".format).unstack()
# Out:
# mcc_description Ценные бумаги: брокеры/дилеры
# gender
# 0.0                                      3.00
# 1.0                                    150.00

# %%
main_table.query('mcc_code == 6211').groupby(['gender','mcc_description']).amount.median().map("{:.2f}".format).unstack()
# Out:
# mcc_description Ценные бумаги: брокеры/дилеры
# gender
# 0.0                                  -6737.75
# 1.0                                 -11229.58

# %%
main_table.query('mcc_code == 5813').groupby(['gender','mcc_description']).amount.count().map("{:.2f}".format).unstack()
# Out:
# mcc_description Бары, коктейль-бары, дискотеки, ночные клубы и таверны — места продажи алкогольных напитков
# gender
# 0.0                                                         146.00
# 1.0                                                         339.00

# %%
main_table.query('mcc_code == 5813').groupby(['gender','mcc_description']).amount.median().map("{:.2f}".format).unstack()
# Out:
# mcc_description Бары, коктейль-бары, дискотеки, ночные клубы и таверны — места продажи алкогольных напитков
# gender
# 0.0                                                       -9387.93
# 1.0                                                      -12667.86

# %%
main_table
# Out:
#          tr_datetime  mcc_code  tr_type      amount term_id  gender  \
# 0         0 10:23:26      4814     1030    -2245.92     NaN     1.0
# 1         6 07:08:31      4814     1030    -5614.79     NaN     1.0
# 2         8 07:06:10      4814     1030    -1122.96     NaN     1.0
# 3        11 08:49:03      4814     1030    -2245.92     NaN     1.0
# 4        11 14:12:08      4814     1030    -2245.92     NaN     1.0
# 5        11 14:15:30      4814     1030    -2245.92     NaN     1.0
# 6        13 11:17:34      4814     1030    -2245.92     NaN     1.0
# 7        18 07:39:05      4814     1030    -2245.92     NaN     1.0
# 8        19 13:24:35      4814     1030     -449.18     NaN     1.0
# 9        19 13:25:31      4814     1030    -1122.96     NaN     1.0
# 10       22 05:47:06      4814     1030    -2245.92     NaN     1.0
# 11       23 12:49:27      4814     1030    -1122.96     NaN     1.0
# 12       29 11:29:57      4814     1030    -1122.96     NaN     1.0
# ...

# %%
main_table.dtypes
# Out:
# tr_datetime          object
# mcc_code              int64
# tr_type               int64
# amount              float64
# term_id              object
# gender              float64
# mcc_description      object
# tr_description       object
# mcc_code+tr_type     object
# tr_day               object
# amount_bucket        object
# tr_hour              object
# dtype: object

# %% [markdown]
# #### Task 5:
# 1. Разбейте расходы (отрицательные значения сумм) на 5 бакетов amount_bucket равного объёма (с помощью pd.qcut), разбив все траты на категории 'Very High', 'High', 'Middle', 'Low', 'Very Low'. (\*)
# 2. Оставшиеся неотрицательные траты отнесится к категории 'Income'.
# 3. Из поля tr_datetime выделите час tr_hour, в который произошла транзакция, как первые 2 цифры до ":". (\**)
# 3. После этого постройте сводную таблицу, значениями в которой является пол gender, индексы - tr_hour, столбцы - amount_bucket.
# 4. Отрисуйте полученные результаты, передав их в функцию plot_pivot_table, расположенную ниже.
# 5. Выберите верные ответы на вопросы ниже.
#
# #### Вопросы:
#     - +1) Ночные поступления денег (01-05 часов) в более чем 85% случаев являются мужскими.
#     - 2) Посмотрев на долю мужчин в поступлениях средств (Income), можно сделать вывод, что количество поступлений средств женщинам в целом больше, чем мужчинам.
#     - +3) Самые низкие траты в 3 часа ночи осуществляются в более 70% случаев женщинами.
#     - 4) Существуют особые часы в мелких тратах, когда женщины тратят намного больше мужчин (>80%)
#     - +5) Посмотрев на долю мужчин в максимальных тратах средств (Very High), можно сделать вывод, что количество высоких тратв каждый возможный час мужчин больше, чем у женщин.
#
# ##### Пояснения:
# (\*) Обратите внимание, что в категории Very High Должны оказаться максимальные по модулю отрицательные транзакции. <br>
# (\**) Например, для строки "0 10:23:26" час будет равен 10, а для строки "6 07:08:31"- 07.

# %%
def plot_pivot_table(pivot_table):
    plt.figure(figsize=(9, 11))
    sns.heatmap(pivot_table, cmap="YlGnBu", annot=True, 
                fmt='.3g', annot_kws={"size": 14, "fontsize": 14})
    plt.xticks(fontsize=15)
    plt.yticks(rotation=0, fontsize=15)
    plt.xlabel('Bucket', size=18)
    plt.ylabel('Hour', fontsize=18)
    plt.title('Gender analysis per bucket and hour', fontsize=20)
    plt.show()

# %%
# Type your code here
main_table['amount_bucket'] = pd.qcut(main_table.amount[main_table.amount < 0], 5, labels=['Very High', 'High', 'Middle', 'Low', 'Very Low'])

# %%
main_table
# Out:
#          tr_datetime  mcc_code  tr_type      amount term_id  gender  \
# 0         0 10:23:26      4814     1030    -2245.92     NaN     1.0
# 1         6 07:08:31      4814     1030    -5614.79     NaN     1.0
# 2         8 07:06:10      4814     1030    -1122.96     NaN     1.0
# 3        11 08:49:03      4814     1030    -2245.92     NaN     1.0
# 4        11 14:12:08      4814     1030    -2245.92     NaN     1.0
# 5        11 14:15:30      4814     1030    -2245.92     NaN     1.0
# 6        13 11:17:34      4814     1030    -2245.92     NaN     1.0
# 7        18 07:39:05      4814     1030    -2245.92     NaN     1.0
# 8        19 13:24:35      4814     1030     -449.18     NaN     1.0
# 9        19 13:25:31      4814     1030    -1122.96     NaN     1.0
# 10       22 05:47:06      4814     1030    -2245.92     NaN     1.0
# 11       23 12:49:27      4814     1030    -1122.96     NaN     1.0
# 12       29 11:29:57      4814     1030    -1122.96     NaN     1.0
# ...

# %%
#main_table.amount_bucket = main_table.amount_bucket.astype(str)
main_table.amount_bucket = main_table.amount_bucket.astype(str).replace('nan', 'Income')

# %%
#re.findall(r'\d+\s(\d+)', '0 10:23:26')
#main_table.tr_datetime

# %%
f = lambda x: re.findall(r'\d+\s(\d+)', x)[0]
main_table['tr_hour'] = main_table.tr_datetime.apply(f)
main_table.head()
# Out:
#    tr_datetime  mcc_code  tr_type   amount term_id  gender  \
# 0   0 10:23:26      4814     1030 -2245.92     NaN     1.0
# 1   6 07:08:31      4814     1030 -5614.79     NaN     1.0
# 2   8 07:06:10      4814     1030 -1122.96     NaN     1.0
# 3  11 08:49:03      4814     1030 -2245.92     NaN     1.0
# 4  11 14:12:08      4814     1030 -2245.92     NaN     1.0
#
#                                      mcc_description  \
# 0  Звонки с использованием телефонов, считывающих...
# 1  Звонки с использованием телефонов, считывающих...
# 2  Звонки с использованием телефонов, считывающих...
# 3  Звонки с использованием телефонов, считывающих...
# 4  Звонки с использованием телефонов, считывающих...
#
#                    tr_description amount_bucket tr_hour
# 0  Оплата услуги. Банкоматы СБ РФ      Very Low      10
# 1  Оплата услуги. Банкоматы СБ РФ           Low      07
# 2  Оплата услуги. Банкоматы СБ РФ      Very Low      07
# 3  Оплата услуги. Банкоматы СБ РФ      Very Low      08
# ...

# %%
#main_table.set_index(['tr_hour'])
t1 = main_table.pivot_table(index='tr_hour', columns='amount_bucket', values='gender')
#print (t1)
#list(t1.columns.values)
t1[['Very High', 'High', 'Middle', 'Low', 'Very Low', 'Income']].head()
#main_table.unstack()
# Out:
# amount_bucket  Very High      High    Middle       Low  Very Low    Income
# tr_hour
# 00              0.578957  0.581928  0.530195  0.544178  0.517352  0.737148
# 01              0.583643  0.594737  0.578947  0.539936  0.450237  0.965922
# 02              0.524804  0.454183  0.489796  0.371014  0.349099  0.965834
# 03              0.533541  0.390374  0.434000  0.358879  0.284333  0.945011
# 04              0.505653  0.438721  0.428981  0.450858  0.290030  0.914473

# %%
plot_pivot_table (t1[['Very High', 'High', 'Middle', 'Low', 'Very Low', 'Income']])

# %%
#plot_pivot_table (main_table.pivot_table(index='tr_hour', columns='amount_bucket', values='gender'))

# %%
#main_table.head()
# Out:
#    tr_datetime  mcc_code  tr_type   amount term_id  gender  \
# 0   0 10:23:26      4814     1030 -2245.92     NaN     1.0
# 1   6 07:08:31      4814     1030 -5614.79     NaN     1.0
# 2   8 07:06:10      4814     1030 -1122.96     NaN     1.0
# 3  11 08:49:03      4814     1030 -2245.92     NaN     1.0
# 4  11 14:12:08      4814     1030 -2245.92     NaN     1.0
#
#                                      mcc_description  \
# 0  Звонки с использованием телефонов, считывающих...
# 1  Звонки с использованием телефонов, считывающих...
# 2  Звонки с использованием телефонов, считывающих...
# 3  Звонки с использованием телефонов, считывающих...
# 4  Звонки с использованием телефонов, считывающих...
#
#                    tr_description mcc_code+tr_type  tr_day amount_bucket  \
# 0  Оплата услуги. Банкоматы СБ РФ         48141030       0      Very Low
# 1  Оплата услуги. Банкоматы СБ РФ         48141030       6           Low
# ...

# %%
main_table.dtypes
# Out:
# tr_datetime          object
# mcc_code              int64
# tr_type               int64
# amount              float64
# term_id              object
# gender              float64
# mcc_description      object
# tr_description       object
# mcc_code+tr_type     object
# tr_day               object
# amount_bucket        object
# tr_hour              object
# dtype: object

# %% [markdown]
# #### Task 6:
# 1. Измените тип поля tr_day на int.
# 2. Выберите из transactions все MCC коды, которые встретились в выборке более чем 60000 раз.
# 3. Сгруппируйте отфильтрованный датафрейм по дню и MCC-коду, получая средние значения суммы amount.
# 4. Далее отрисуйте зависимость средних сумм (может пригодится метод unstack()) по каждому из MCC-кодов по дням.
# 5. Выберите верные ответы на вопросы ниже.
#
# #### Вопросы:
#     - +1) 2 из полученных MCC-кодов связаны с финансовыми институтами
#     - +2) 2 MCC кода, связанные со снятием наличности имеют в целом разные знаки (в одном случае почти везде - траты, в другом - пополнения)
#     - 3) Бакалейные магазины обладают максимальными средними тратами среди выбранных MCC-кодов
#     - +4) Денежные переводы имеют как минимум 3 явных минимума средних
#     - 5) Категория "Звонки с использованием телефонов, считывающих магнитную ленту" имеет визуально очень большую дисперсию.

# %%
main_table.tr_day = main_table.tr_day.astype(int)

# %%
transactions.head()
# Out:
#             tr_datetime  mcc_code  tr_type    amount term_id
# customer_id
# 39026145     0 10:23:26      4814     1030  -2245.92     NaN
# 39026145     1 10:19:29      6011     7010  56147.89     NaN
# 39026145     1 10:20:56      4829     2330 -56147.89     NaN
# 39026145     1 10:39:54      5499     1010  -1392.47     NaN
# 39026145     2 15:33:42      5499     1010   -920.83     NaN

# %%
main_table.dtypes
f = lambda x: re.findall(r'(\d+)\s', x)[0]
transactions['tr_day'] = transactions.tr_datetime.apply(f)

# %%
#transactions = pd.merge(t6, tr_mcc_codes, on='mcc_code')
print (transactions.head())
f = lambda x: x.mcc_code.count() > 60000
transactions_T6 = transactions.groupby(['mcc_code']).filter(f)
# Out:
#             tr_datetime  mcc_code  tr_type    amount term_id tr_day
# customer_id
# 39026145     0 10:23:26      4814     1030  -2245.92     NaN      0
# 39026145     1 10:19:29      6011     7010  56147.89     NaN      1
# 39026145     1 10:20:56      4829     2330 -56147.89     NaN      1
# 39026145     1 10:39:54      5499     1010  -1392.47     NaN      1
# 39026145     2 15:33:42      5499     1010   -920.83     NaN      2

# %%
#transactions_T6_ = transactions.groupby(['mcc_code'])
transactions_T6.count()
# Out:
# tr_datetime    741379
# mcc_code       741379
# tr_type        741379
# amount         741379
# term_id        427306
# tr_day         741379
# dtype: int64

# %%
transactions_T6.head()
# Out:
#             tr_datetime  mcc_code  tr_type    amount term_id tr_day
# customer_id
# 39026145     0 10:23:26      4814     1030  -2245.92     NaN      0
# 39026145     1 10:19:29      6011     7010  56147.89     NaN      1
# 39026145     1 10:20:56      4829     2330 -56147.89     NaN      1
# 39026145     6 07:08:31      4814     1030  -5614.79     NaN      6
# 39026145     8 06:55:51      6011     2010  -4491.83     NaN      8

# %%
transactions_T6 = transactions_T6.set_index(['tr_day', 'mcc_code'])
t6 = transactions_T6.groupby(level = ['tr_day', 'mcc_code']).mean()

# %%
t6.head()
# Out:
#                      tr_type         amount
# tr_day mcc_code
# 0      4814      1031.347962   -5631.316489
#        4829      2630.189873 -214754.866266
#        5411      1052.323651  -15462.567344
#        6010      6886.615584   90390.672987
#        6011      2771.200389  -55388.115175

# %%
#t6 = pd.merge(t6, tr_mcc_codes, on='mcc_code')

# %%
t6.head()
#t6 = t6.set_index('tr_day', 'mcc_description')
# Out:
#                      tr_type         amount
# tr_day mcc_code
# 0      4814      1031.347962   -5631.316489
#        4829      2630.189873 -214754.866266
#        5411      1052.323651  -15462.567344
#        6010      6886.615584   90390.672987
#        6011      2771.200389  -55388.115175

# %%
t6.head()
# Out:
#                      tr_type         amount
# tr_day mcc_code
# 0      4814      1031.347962   -5631.316489
#        4829      2630.189873 -214754.866266
#        5411      1052.323651  -15462.567344
#        6010      6886.615584   90390.672987
#        6011      2771.200389  -55388.115175

# %%
t6['amount'].unstack()
# Out:
# mcc_code         4814           4829          5411           6010  \
# tr_day
# 0        -5631.316489 -214754.866266 -15462.567344   90390.672987
# 1        -6375.587685 -158317.573750 -17770.243543   57658.709639
# 10       -5389.918248 -228132.640744 -11786.959640   86468.790485
# 100      -4781.903545 -194239.654396 -19120.905404   37740.259740
# 101      -4855.970763 -168552.888955 -12993.806543   76511.451009
# 102      -4898.253433 -222445.728914 -11915.814186   81753.493581
# 103      -5126.845586 -266514.786429 -13859.854398   72555.299312
# 104      -3928.356794 -161350.809070 -13882.688272   41252.076326
# 105      -4715.444963 -170171.112030 -18736.826441   68901.124852
# 106      -4632.270769 -163910.591736 -18367.305821   55318.538057
# 107      -4796.981100 -232008.980336 -16659.666133   52919.948831
# 108      -4807.311932 -175384.730178 -13838.258091   99048.899858
# 109      -6028.946008 -294817.862389 -11627.835000   93082.371642
# ...

# %%
tr_mcc_codes.index
# Out:
# Int64Index([ 742, 1711, 1731, 1799, 2741, 3000, 3351, 3501, 4111, 4112,
#             ...
#             8299, 8398, 8641, 8699, 8999, 9211, 9222, 9311, 9399, 9402],
#            dtype='int64', name='mcc_code', length=184)

# %%
tr_mcc_codes.loc[[4814, 4829, 5411, 6010, 6011]]
# Out:
#                                             mcc_description
# mcc_code
# 4814      Звонки с использованием телефонов, считывающих...
# 4829                                      Денежные переводы
# 5411                      Бакалейные магазины, супермаркеты
# 6010       Финансовые институты — снятие наличности вручную
# 6011      Финансовые институты — снятие наличности автом...
